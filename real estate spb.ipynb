# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# <b>Привет!</b>
#
# Меня зовут Сороколетов Илья и я буду проверять твой проект.
#
# Предлагаю общаться на «**ты**», но если тебе будет комфортнее общаться на «**вы**», то сообщи об этом в комментариях)
#
#
# Для твоего удобства, я буду выделять свои комментарии следующим образом:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b> Самые важные замечания. Они указывают на ключевые моменты, которые влияют на конечный результат проекта. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b> Советы или замечания, которые помогут сделать твою работу лучше, но необязательны к выполнению.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b> Так я выделяю все остальные комментарии.</div>
#
#
# Пометками <b>v1-v2-v3-...</b> я буду отмечать версию проверки. Так ты сможешь быстро найти мои новые комментарии.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения, например вот так:
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# </div>
#
# <b>Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии.</b> Если ты оставляешь свои комментарии, то делай это под моими, чтобы сообщения были расположены в хронологическом порядке. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Перед отправкой работы я рекомендую нажимать Kernel -> Restart & Run All. Это перезапустит ядро и по очереди выполнит все ячейки. Так ты сможешь проверить, что всё работает корректно. Кнопка Kernel находится в панели сверху
#
# Обязательно задавай вопросы если они возникнут, а я перехожу к проверке)
#
# P.S. На всякий случай, я оставлю пустой шаблон для твоих комментариев ниже. Кликни два раза на мой комментарий, скопируй последние четыре строчки кода и вставляй их в пустую ячейку там, где ты хочешь оставить комментарий. Не забудь только перед этим сменить тип ячейки на Markdown. Быстро это можно сделать так: кликнуть на ячейку - нажать ESC - нажать M.
#
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Удали этот текст и вместо него напиши свой комментарий 🙂
# </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Проверим-таблицу-на-пропущенные-значения" data-toc-modified-id="Проверим-таблицу-на-пропущенные-значения-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Проверим таблицу на пропущенные значения</a></span></li><li><span><a href="#Сначала-разберемся-с-пропусками,-которые-оставили-люди,-заполнявшие-данные:" data-toc-modified-id="Сначала-разберемся-с-пропусками,-которые-оставили-люди,-заполнявшие-данные:-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сначала разберемся с пропусками, которые оставили люди, заполнявшие данные:</a></span></li><li><span><a href="#Перейдем-к-пропускам,-полученным-автоматически:" data-toc-modified-id="Перейдем-к-пропускам,-полученным-автоматически:-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Перейдем к пропускам, полученным автоматически:</a></span></li><li><span><a href="#Изменим-типы-данных-в-столбцах" data-toc-modified-id="Изменим-типы-данных-в-столбцах-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Изменим типы данных в столбцах</a></span></li><li><span><a href="#Устраним-неявные-дубликаты" data-toc-modified-id="Устраним-неявные-дубликаты-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Устраним неявные дубликаты</a></span></li></ul></li><li><span><a href="#Расширим-таблицу" data-toc-modified-id="Расширим-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расширим таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучим-перечисленные-ниже-параметры-объектов-и-построим-отдельные-гистограммы-для-каждого-из-этих-параметров." data-toc-modified-id="Изучим-перечисленные-ниже-параметры-объектов-и-построим-отдельные-гистограммы-для-каждого-из-этих-параметров.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучим перечисленные ниже параметры объектов и построим отдельные гистограммы для каждого из этих параметров.</a></span><ul class="toc-item"><li><span><a href="#Общая-площадь" data-toc-modified-id="Общая-площадь-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Общая площадь</a></span></li><li><span><a href="#Жилая-площадь" data-toc-modified-id="Жилая-площадь-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Жилая площадь</a></span></li><li><span><a href="#Площадь-кухни" data-toc-modified-id="Площадь-кухни-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Площадь кухни</a></span></li><li><span><a href="#Цена-объекта" data-toc-modified-id="Цена-объекта-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Цена объекта</a></span></li><li><span><a href="#Количество-комнат" data-toc-modified-id="Количество-комнат-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Количество комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span>Высота потолков</a></span></li><li><span><a href="#Тип-этажа-квартиры" data-toc-modified-id="Тип-этажа-квартиры-4.1.7"><span class="toc-item-num">4.1.7&nbsp;&nbsp;</span>Тип этажа квартиры</a></span></li><li><span><a href="#Общее-количество-этажей-в-доме" data-toc-modified-id="Общее-количество-этажей-в-доме-4.1.8"><span class="toc-item-num">4.1.8&nbsp;&nbsp;</span>Общее количество этажей в доме</a></span></li><li><span><a href="#Расстояние-до-центра-города-в-метрах" data-toc-modified-id="Расстояние-до-центра-города-в-метрах-4.1.9"><span class="toc-item-num">4.1.9&nbsp;&nbsp;</span>Расстояние до центра города в метрах</a></span></li><li><span><a href="#Расстояние-до-ближайшего-парка" data-toc-modified-id="Расстояние-до-ближайшего-парка-4.1.10"><span class="toc-item-num">4.1.10&nbsp;&nbsp;</span>Расстояние до ближайшего парка</a></span></li></ul></li><li><span><a href="#Изучите,-как-быстро-продавались-квартиры" data-toc-modified-id="Изучите,-как-быстро-продавались-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучите, как быстро продавались квартиры</a></span></li><li><span><a href="#Взаимосвязь-данных" data-toc-modified-id="Взаимосвязь-данных-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Взаимосвязь данных</a></span><ul class="toc-item"><li><span><a href="#Взаимосвязь-с-общей-площадью" data-toc-modified-id="Взаимосвязь-с-общей-площадью-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Взаимосвязь с общей площадью</a></span></li><li><span><a href="#Взаимосвязь-с-жилой-площадью" data-toc-modified-id="Взаимосвязь-с-жилой-площадью-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Взаимосвязь с жилой площадью</a></span></li><li><span><a href="#Взаимосвязь-с-площадью-кухни" data-toc-modified-id="Взаимосвязь-с-площадью-кухни-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Взаимосвязь с площадью кухни</a></span></li><li><span><a href="#Взаимосвязь-с-количеством-комнат" data-toc-modified-id="Взаимосвязь-с-количеством-комнат-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Взаимосвязь с количеством комнат</a></span></li><li><span><a href="#Взаимосвязь-с-этажом,-на-котором-расположена-квартира" data-toc-modified-id="Взаимосвязь-с-этажом,-на-котором-расположена-квартира-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Взаимосвязь с этажом, на котором расположена квартира</a></span></li><li><span><a href="#Взаимосвязь-от-даты-размещения" data-toc-modified-id="Взаимосвязь-от-даты-размещения-4.3.6"><span class="toc-item-num">4.3.6&nbsp;&nbsp;</span>Взаимосвязь от даты размещения</a></span><ul class="toc-item"><li><span><a href="#День-недели" data-toc-modified-id="День-недели-4.3.6.1"><span class="toc-item-num">4.3.6.1&nbsp;&nbsp;</span>День недели</a></span></li><li><span><a href="#Месяц" data-toc-modified-id="Месяц-4.3.6.2"><span class="toc-item-num">4.3.6.2&nbsp;&nbsp;</span>Месяц</a></span></li><li><span><a href="#Год" data-toc-modified-id="Год-4.3.6.3"><span class="toc-item-num">4.3.6.3&nbsp;&nbsp;</span>Год</a></span></li></ul></li></ul></li><li><span><a href="#Топ-10-населенных-пунктов-по-цене-за-квадратный-метр" data-toc-modified-id="Топ-10-населенных-пунктов-по-цене-за-квадратный-метр-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Топ 10 населенных пунктов по цене за квадратный метр</a></span></li><li><span><a href="#Найдем-среднюю-стоимость-квартир-по-мере-удаления-от-центра-города" data-toc-modified-id="Найдем-среднюю-стоимость-квартир-по-мере-удаления-от-центра-города-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Найдем среднюю стоимость квартир по мере удаления от центра города</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b> Привет! Я случайно загрузил новую версию тетрадки, а твою не скачал. Накосячил, короче) Извини!</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Бывает) Перехожу к проверке!
# </div>

# %% [markdown]
# # Проект: Исследовательский анализ данных
# # Исследование объявлений о продаже квартир
# Описание проекта
#
# Цель проекта - определить рыночную стоимость объектов недвижимости в Санкт-Петербурге и соседних населенных пунктах на основе данных сервиса Яндекс Недвижимость
#
# Задачи проекта:
# 1. Научиться определять рыночную стоимость объектов недвижимости
# 2. Провести предобработку данных
# 2. Провести исследовательский анализ данных и установите параметры, влияющие на цену объектов
#
# Часть данных получена от пользователей, другая часть автоматически получена на основе картографических данных (например, удаленность от объектов инфраструктуры, количество парков и водоемов в округе)
#
# План работы:
#
# 1. Ознакомиться с данными
# 2. Выполнить предобработку данных
# 3. Провести исследовательский анализ
# 4. Написать вывод исследования
# 5. Дать рекомендации
#
# Описание данных:
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — общая площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Молодец, что добавляешь краткое описание задачи. Это поможет тебе быстро вспомнить о чем проект, если спустя время ты решишь к нему вернуться)
# </div>

# %% [markdown]
# ## Обзор данных

# %%
# импортируем библиотеку пандас для работы с таблицами
# импортируем библиотеку матплотлиб для работы с графиками
import pandas as pd
import matplotlib.pyplot as plt

# %%
# открываем исходный файл и сохраняем в переменную data
try:
    data = pd.read_csv('/Users/sergio/Downloads/Data Analysis/yandex_projects/real_estate/datasets/real_estate_data.csv', sep='\t')
except:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b> Путь к файлу исправил!</div>

# %%
# добавим настройки для отображения всех строк и всех столбцов для удобства просмотра
pd.set_option('display.max_columns', None)
pd.set_option("display.max_rows", None)

# %%
# выводим первые 20 строчек датафрейма на экран
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отлично, что ты увеличиваешь лимит для отображаемых столбцов, чтобы было видно всю таблицу
# </div>

# %% [markdown]
# На первый взгляд видно, что в некоторых колонках стоит некоректный тип данных. И заметим факт пропущенных значений в некоторых строках.

# %%
# методом describe выводим числовую информацию о датафрейме
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %%
# выводим основную информацию о датафрейме
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Мы видим что в таблице 23699 строк, 22 колонки, есть пропущенные значения, разные типы данных, объем таблицы более 3.7 MB

# %%
# построим гистограмму для всех числовых столбцов таблицы
data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Графики построено верно!
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Проверим таблицу на пропущенные значения

# %%
# выводим общее количество пропущенных значений для каждого столбца 
# и долю пропущенных значений от всех строк в столбце
for column in data.columns:
    columnna = data[column].isna().sum()
    colunnshare = data[column].isna().sum() / data[column].isna().count() * 100
    print(f'{column}:\n Пропусков: {columnna}. Доля: {colunnshare:.2f}% \n')
# Out:
# total_images:
#  Пропусков: 0. Доля: 0.00%
#
# last_price:
#  Пропусков: 0. Доля: 0.00%
#
# total_area:
#  Пропусков: 0. Доля: 0.00%
#
# first_day_exposition:
#  Пропусков: 0. Доля: 0.00%
#
# rooms:
#  Пропусков: 0. Доля: 0.00%
#
# ceiling_height:
#  Пропусков: 9195. Доля: 38.80%
#
# floors_total:
#  Пропусков: 86. Доля: 0.36%
#
# living_area:
#  Пропусков: 1903. Доля: 8.03%
#
# floor:
#  Пропусков: 0. Доля: 0.00%
#
# is_apartment:
#  Пропусков: 20924. Доля: 88.29%
#
# studio:
#  Пропусков: 0. Доля: 0.00%
#
# open_plan:
#  Пропусков: 0. Доля: 0.00%
#
# kitchen_area:
#  Пропусков: 2278. Доля: 9.61%
#
# balcony:
#  Пропусков: 11519. Доля: 48.61%
#
# locality_name:
#  Пропусков: 49. Доля: 0.21%
#
# airports_nearest:
#  Пропусков: 5542. Доля: 23.38%
#
# cityCenters_nearest:
#  Пропусков: 5519. Доля: 23.29%
#
# parks_around3000:
#  Пропусков: 5518. Доля: 23.28%
#
# parks_nearest:
#  Пропусков: 15620. Доля: 65.91%
#
# ponds_around3000:
#  Пропусков: 5518. Доля: 23.28%
#
# ponds_nearest:
# ...

# %%
# выводим общее количество пропущенных значений для каждого столбца
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Наблюдаем много столбцов с пропущенными значениями.
#
# Возможные причины пропусков:
# 1. человеческий фактор - продавцы не указывают информацию об объектах;
# 2. техническая ошибка
# 3. данные теряются при конвертации файла
#
# Попробуем упорядочить столбцы.

# %% [markdown]
# ### Сначала разберемся с пропусками, которые оставили люди, заполнявшие данные:

# %% [markdown]
# В колонках:
#
# - ceiling_height (высота потолков) пропуски, скорее всего, из-за недостатка информации у продавца. Высоту потолков мы можем предсказать, логично заполнить пропуски медианой.
#
# - floors_total (всего этажей в доме) пропусков всего 86, возможно, эти пропуски были допущены по невнимательности. Строчки с этими пропусками можно удалить, не боясь искажения выводов.
#
# - living_area (жилая площадь в квадратных метрах) и kitchen_area (площадь кухни в квадратных метрах) пропуски скорее всего из-за недостатка информации у продавца. Попробуем восстановить эти пропуски
#
#
# - balcony (число балконов) пропуски заменим на число 0, потому что, скорее всего, продавец не указал число балконов, потому что в его квартире их нет.
#
# - locality_name всего 49 пропусков - удалим строчки с пропусками, так как эти данные не восстановить
#
# - is_apartment пропуски скорее всего, потому что продавец не указал апартаменты его объект или нет. Так как доля апартаментов на рынке существенно меньше доли квартир, логично предположить, что это были квартиры, поэтому заменим пропуски на False

# %%
# заполним пропуски на медиану в столбце ceiling_height
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Согласен с таким решением для столбца с высотой потолков, так как основная часть данных в этом столбце находится в небольшом диапазоне.
# </div>

# %% [markdown]
# Пропуски в столбце апартаменты заполним на False, так как доля апартаментов по отношению к квартирам очень мала. Скорее всего продавцы не заполняли эту строчку, потому что их объект - квартира.

# %%
# заполняем пропуски в is_apartment на False
data['is_apartment'] = data['is_apartment'].fillna(value=False)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👌
# </div>

# %% [markdown]
# Скорее всего продавцы не указывали количество балконов, потому что их в объекте нет. Поэтому заполняем пропуски нулями.

# %%
# заменим пропущенные значения в столбце balcony на 0
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👌
# </div>

# %%
# удалим строки, которые решили удалить
data = data.dropna(subset = ['locality_name', 'floors_total'])

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Удалить пропуски в этих столбцах - это хорошее решение.
# </div>

# %% [markdown]
# Для заполнения пропусков в столбце жилая площадь воспользуемся соотношением величин. Корреляция между столбцами жилая и общая площадь почти 1, значит корреляция положительная.

# %%
# методом corr находим корреляцию Пирсона
data['living_area'].corr(data['total_area'])
# Out:
# 0.9397711143610334

# %% [markdown]
# Найдем среднее соотношение всех заполненных данных

# %%
# методом mean находим среднее 
(data['living_area'] / data['total_area']).mean()
# Out:
# 0.5649371748241468

# %% [markdown]
# Циклом заполняем все пропущенные значения в столбце площадь кухни на произведение среднего соотношения и общей площади квартиры

# %%
# цикл, заполняющий пропуски 
for value in data['living_area'].isna():
    data.loc[data['living_area'].isna(), 'living_area'] = data['total_area'] * 0.56

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Прекрасный способ для замены! 👏🏻👏🏻👏🏻
# </div>

# %% [markdown]
# Попробуем сделать так же с площадью кухни

# %%
# методом corr находим корреляцию Пирсона
data['kitchen_area'].corr(data['total_area'])
# Out:
# 0.6092476784548312

# %% [markdown]
# Здесь корреляция не сильно выражена. Значит будем заполнять с помощью пропорции: общая площадь * 0.9 - (площадь кухни + площадь общая)
#
# Здесь умножаем на 0.9, потому что 10% площади оставляем для нежилых помещений и стен
#
# Для начала проверим сколько пропусков в строках living_area и total_area там, где уже есть пропуски в kitchen_area

# %%
# делаем срез данных и выводим сумму пропусков в интересующих нас данных
data.query('kitchen_area.isna()')[['living_area','total_area']].isna().sum()
# Out:
# living_area    0
# total_area     0
# dtype: int64

# %% [markdown]
# Пропусков нет, значит ничего нам не помешает. Напишем цикл, который заполнит пропуски

# %%
# цикл, заполняющий пропуски 
for value in data['kitchen_area'].isna():
    data.loc[data['kitchen_area'].isna(), 'kitchen_area'] = data['total_area'] * 0.9 - data['living_area']

# %% [markdown]
# Проверим еще сколько строк, где такое соотношение не верно

# %%
# делаем сред данных и считаем все строки
data.query('total_area * 0.9 < (kitchen_area + living_area)').count()
# Out:
# total_images            492
# last_price              492
# total_area              492
# first_day_exposition    492
# rooms                   492
# ceiling_height          492
# floors_total            492
# living_area             492
# floor                   492
# is_apartment            492
# studio                  492
# open_plan               492
# kitchen_area            492
# balcony                 492
# locality_name           492
# airports_nearest        356
# cityCenters_nearest     356
# parks_around3000        356
# parks_nearest           183
# ponds_around3000        356
# ponds_nearest           194
# days_exposition         408
# dtype: int64

# %% [markdown]
# Всего 500 строк, где данные искажены. Они нам не помешают и скорее всего не изменят общую картину

# %%
# проверим результат
data[['ceiling_height', 'is_apartment', 'balcony', 'floors_total', 'locality_name']].isna().sum()
# Out:
# ceiling_height    0
# is_apartment      0
# balcony           0
# floors_total      0
# locality_name     0
# dtype: int64

# %% [markdown]
# В этих столбцах пропусков больше нет. Двигаемся дальше!

# %% [markdown]
# ### Перейдем к пропускам, полученным автоматически:

# %% [markdown]
# Не забываем, что эти данные были получены автоматически на основе картографических данных.
#
# В столбцах:
#
# - parks_around3000 и ponds_around3000 есть пропущенные значения. Однако, нам кажется заполнять их нулями не логично, так как в данных есть нулевые значения - это видно из графиков ниже - значит при автоматическом заполнении парков или озер в радиусе 3 км не было найдено. Если мы заполним пропуски нулями, то исказим данные. Пока оставим эти пропуски как есть;

# %%
# построим гистограммы для столбцов с данными об озерах и парках в радиусе 3км 
data['ponds_around3000'].hist()
plt.show()
data['parks_around3000'].hist()
plt.show()

# %% [markdown]
# - airports_nearest, cityCenters_nearest, parks_nearest, ponds_nearest есть пропущенные значения. Мы не знаем расположение объектов, поэтому заполнить медианой пропуски мы не можем, потому что рискуем исказить выводы. Заполнить нулями тоже не можем. Логичную замену здесь предложить мы не можем, поэтому оставляем пропуски
#
# - days_exposition пропуски пока оставим как есть

# %%
# еще раз проверим пропуски во всем датафрейме
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5524
# cityCenters_nearest      5501
# parks_around3000         5500
# parks_nearest           15535
# ponds_around3000         5500
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %% [markdown]
# <div class="alert alert-info"> <b>Привет, ревьюер! Мне кажется, я не прав, что оставляю пропуски. Но не могу придумать и логически обосновать чем их заменить или заполнить. Подскажи, пожалуйста:</b> </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Это наоборот верное решение. Тут нет подходящего способа для замены
# </div>

# %% [markdown]
# ### Изменим типы данных в столбцах

# %% [markdown]
# Предлагаем поменять тип данных в некоторых столбцах.
#
# Почему это важно?
# - для сохранениния памяти компьютера
# - для удобства обработки данных
# - для улучшения восприятия информации

# %% [markdown]
# Изменим тип данных в этих столбцах на следующие типы данных:
#
#
# С float на int (целочистленное значение):
# - last_price
# - floors_total
# - balcony
#
# C float64 на float32 для экономии памяти:
# - total_area
# - ceiling_height
# - living_area
# - kitchen_area
# - airports_nearest
# - cityCenters_nearest
# - parks_around3000
# - parks_nearest
# - ponds_around3000
# - ponds_nearest
# - days_exposition'
#
# На datetime (дата и время):
# - first_day_exposition

# %%
# цикл, меняющий тип данных в выбранных столбцах с float на int 
data[['last_price', 'floors_total', 'balcony']] = data[['last_price', 'floors_total', 'balcony']].astype(int)

# %%
# команда, меняющая тип данных в выбранных столбцах с float64 на float32
data[['total_area', 'ceiling_height', 'living_area', 'kitchen_area', 'airports_nearest', 'cityCenters_nearest', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'days_exposition']] = data[['total_area', 'ceiling_height', 'living_area', 'kitchen_area', 'airports_nearest', 'cityCenters_nearest', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'days_exposition']].astype('float32')

# %%
# изменим тип данных в столбце с датой и временем на соответствующий
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
# проверим изменились ли типы данных
data.dtypes
# Out:
# total_images                     int64
# last_price                       int64
# total_area                     float32
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float32
# floors_total                     int64
# living_area                    float32
# floor                            int64
# is_apartment                      bool
# studio                            bool
# open_plan                         bool
# kitchen_area                   float32
# balcony                          int64
# locality_name                   object
# airports_nearest               float32
# cityCenters_nearest            float32
# parks_around3000               float32
# parks_nearest                  float32
# ponds_around3000               float32
# ponds_nearest                  float32
# days_exposition                float32
# dtype: object

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Изменение типов данных проведено верно. Можно ещё заменить тип данных с float64 на float32 для экономии памяти.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Перевел на float32. А на int32 тоже можно перевести? </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Можно)
# </div>

# %% [markdown]
# ### Устраним неявные дубликаты

# %% [markdown]
# В датафрейме есть столбец с названиями населенных пунктов. Проверим его на неявные дубликаты!

# %% [markdown]
# Изучим уникальные значения столбца с названиями населенных пунктов

# %%
# вызовем метод unique для вывода всех уникальных значений 
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Присутствуют неявные дубликаты, избавимся от них:
#
# - заменим букву ё на е
# - приведем все варианты названия поселка к единому названию
# - деревни и села оставим как есть

# %%
# методом replace заменяем значения в столбце locality_name
data['locality_name'] = (
    data['locality_name']
    .str.replace('ё', 'е')
    .replace(['городской поселок', 'поселок городского типа', 'коттеджный поселок', 'садовое товарищество', 'садовое товарищество', 'садоводческое некоммерческое товарищество', 'поселок при железнодорожной станции'], 'поселок', regex=True)
)

# %%
# проверим результат
data['locality_name'].value_counts()
# Out:
# Санкт-Петербург                    15651
# поселок Мурино                       552
# поселок Шушары                       439
# Всеволожск                           398
# Пушкин                               369
# Колпино                              338
# поселок Парголово                    327
# Гатчина                              307
# деревня Кудрово                      299
# Выборг                               237
# Петергоф                             201
# Сестрорецк                           183
# Красное Село                         176
# Кудрово                              171
# деревня Новое Девяткино              143
# Сертолово                            142
# Ломоносов                            133
# Кириши                               125
# поселок Бугры                        113
# Сланцы                               112
# Волхов                               111
# Тосно                                104
# Кингисепп                            104
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Супер! Здесь всё верно)
# </div>

# %% [markdown]
# ## Расширим таблицу

# %% [markdown]
# Добавим в таблицу новые столбцы со следующими параметрами

# %% [markdown]
# Столбец с ценой одного квадратного метра с округлением до двух знаков после запятой

# %%
# поделим стоимость объекта на его общую площадь и затем округлим до двух знаков после запятой
data['sqm_price'] = (data['last_price'] / data['total_area']).round(2)

# %% [markdown]
# Стоблец с днем недели публикации объявления (0 — понедельник, 1 — вторник и так далее)

# %%
# добавим столбец с днем недели публикации объявления
data['weekday_published'] = data['first_day_exposition'].dt.weekday

# %% [markdown]
# Столбец с номером месяца публикации объявления

# %%
# добавим столбец с месяцем публикации объявления
data['month_published'] = data['first_day_exposition'].dt.month

# %% [markdown]
# Столбец с годом публикации объявления

# %%
# добавим столбец с годом публикации объявления
data['year_published'] = data['first_day_exposition'].dt.year

# %% [markdown]
# Столбец с категорией этажей
#
# Напишем функцию, которая категоризирует этажи

# %%
# функция для строки, возвращающая категорию этажа
def categorize_floor(row):
    
    floor = row['floor']
    total_floors = row['floors_total']
    # проверим что указанный этаж не больше последнего этажа в доме
    if 0 < floor <= total_floors:
    
        if floor == 1:
            return 'первый'
        if floor == total_floors:
            return 'последний'
        else:
            return 'другой'
    else:
        return 'неверно указан этаж'

# %%
# применим функцию к новому столбцу с категориями этажей
data['floor_category'] = data.apply(categorize_floor, axis=1)

# %% [markdown]
# Столбец с расстоянием до центра города в километрах

# %%
# создадим новый столбец с расстоянием до центра в км
# переводим метры в км и округляем до целых значений
data['cityCenter_distance_km'] = (data['cityCenters_nearest'] / 1000).round(0)

# %%
# проверим результат
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000  108.000000           2019-03-07      3
# 1             7     3350000   40.400002           2018-12-04      1
# 2            10     5196000   56.000000           2015-08-20      2
# 3             0    64900000  159.000000           2015-07-24      3
# 4             2    10000000  100.000000           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16    51.000000      8         False   False
# 1            2.65            11    18.600000      1         False   False
# 2            2.65             5    34.299999      4         False   False
# 3            2.65            14    89.040001      9         False   False
# 4            3.03            14    32.000000     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Все необходимые колонки добавлены. Идём дальше)
# </div>

# %% [markdown]
# ##  Исследовательский анализ данных

# %% [markdown]
# ### Изучим перечисленные ниже параметры объектов и построим отдельные гистограммы для каждого из этих параметров.
#
# Попробуем обработать аномалии, если они есть.

# %% [markdown]
# #### Общая площадь

# %% [markdown]
# Построим гистограмму и диаграмму размаха для параметра общая площадь:

# %%
# используем метод hist для построения гистограммы
data.hist('total_area');

# %% [markdown]
# Видим, что большая часть распределения лежит в диапазоне от 0 до 200, но на таком графике не видно деталей, попробуем взглянуть поближе. Сразу увеличим число корзин для наглядности

# %%
# параметром bins задаем число корзин, параметром range задаем масштаб
data.hist('total_area', bins=100, range=(0, 300));
plt.show()
# строим диаграму размаха с масштабом от 0 до 200
data.boxplot('total_area');
plt.ylim(0, 200);

# %% [markdown]
# Квартиры с площадью больше 100 - уже редки. На участке более 250 гистогамма уже сливается с нулем, значит таких квартир единицы.
#
# По диаграме размаха выбросы это все значения после 115
#
# Примем верхнюю границу в 150 квадратных метров.

# %%
# проверим сколько строк мы потеряем
len(data.query('total_area > 150'))
# Out:
# 561

# %% [markdown]
# Если отбросить эти значения, много данных не потеряется
#
# Построим гистограмму по новым данным с помощью среза:

# %%
# методом query делаем срез данных
data.query('total_area < 150').hist('total_area', bins=100, range=(0, 150));

# %%
# перезапишем в переменную датасет, с которым будем работать дальше
data_filtered = data.query('total_area < 150')

# %% [markdown]
# #### Жилая площадь

# %% [markdown]
# Построим гистограмму и диаграмму размаха для параметра жилая площадь:

# %%
# используем метод hist для построения гистограммы
data_filtered.hist('living_area');

# %% [markdown]
# Большинство значений лежит перед отметкой 100. Увеличим масштаб гистограммы и посмотрим ближе; сразу увеличим количество корзин

# %%
data_filtered.hist('living_area',bins=50, range=(0, 120));
plt.show()
# здесь же построим диаграмму размаха методом boxplot()
data_filtered.boxplot('living_area');
plt.ylim(0,100);

# %% [markdown]
# После отметки 60 квадратных метров значения уже редки, после отметки в 100 значения сливаются с нулем.
#
# По ящику с усами выбросы - все что после 80

# %%
# проверим сколько строк мы потеряем
len(data_filtered.query('living_area > 80'))
# Out:
# 248

# %% [markdown]
# Примем верхнюю границу в 80 квадратных метров, так много данных не потеряется
#
# Построим гистограмму по новым данным с помощью среза:

# %%
# метbодом query делаем срез данных
data_filtered.query('living_area < 80').hist('living_area', bins = 100);

# %% [markdown]
# Эти два пика очень настораживают. Но что это?

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Илья, по твоему мнению - как интерпретировать этот график? </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Можно было бы сделать вывод, что чаще всего встречаются типовые квартиры (или комнаты) с площадью до 20 метров и в районе 30, но перед тем как делать такие вывод нужно посмотреть на количество значений в этих диапазонах.
# </div>

# %%
# перезапишем в переменную датасет, с которым будем работать дальше
data_filtered = data_filtered.query('living_area < 80')

# %% [markdown]
# #### Площадь кухни

# %% [markdown]
# Построим гистограмму и диаграмму размаха для параметра площадь кухни:

# %%
# используем метод hist для построения гистограммы
data_filtered.hist('kitchen_area');

# %% [markdown]
# Увеличим масштаб и посмотрим распределение большинства значений

# %%
data_filtered.hist('kitchen_area',bins=50, range=(0, 50));
plt.show()
data_filtered.boxplot('kitchen_area');
plt.ylim(0,30);

# %% [markdown]
# После отметки 30 квадратных метров значения уже редки, после отметки в 40 значения сливаются с нулем.
#
# По ящику с усами выбросы - все что после 20

# %%
len(data_filtered.query('kitchen_area > 30'))
# Out:
# 346

# %% [markdown]
# Примем верхнюю границу в 30 квадратных метров, так много данных не потеряется
#
# Построим гистограмму по новым данным с помощью среза:

# %%
# методом query делаем срез данных
data_filtered.query('kitchen_area < 30').hist('kitchen_area', bins = 50);

# %%
# перезапишем в переменную датасет, с которым будем работать дальше
data_filtered = data_filtered.query('kitchen_area < 30')

# %% [markdown]
# #### Цена объекта

# %% [markdown]
# Построим гистограмму и диаграмму размаха для параметра цена объекта:

# %%
# разделим все значения на 1 млн для удобства восприятия
data_filtered['last_price'] = data_filtered['last_price'] / 1000000

# %%
# используем метод hist для построения гистограммы
data_filtered.hist('last_price');

# %% [markdown]
# Большинство значений лежит перед отметкой 100000000. Увеличим масштаб гистограммы и посмотрим ближе; сразу увеличим количество корзин

# %%
data_filtered.hist('last_price',bins=200, range=(0, 30));
plt.show()
data_filtered.boxplot('last_price');
plt.ylim(0,15);

# %%
len(data_filtered.query('last_price > 20'))
# Out:
# 186

# %% [markdown]
# Цены больше 10 000 000 уже редки. После 30 000 000 гистограмма сливается с нулем.
# Определим верхнюю границу в 12 000 000, много данных не потеряется. Нижнюю границу определять не будем, так как там слишком мало данных, онм не исказят результаты
#
# Построим график по срезу:

# %%
# методом query делаем срез данных
data_filtered.query('last_price < 20').hist('last_price', bins = 50);

# %%
# перезапишем в переменную датасет, с которым будем работать дальше
data_filtered = data_filtered.query('last_price < 20')

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Тут можно разделить все значения в столбце last_price на 1 млн, чтобы они пришли в более понятный вид)
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> На самом деле стало более понятно! спасибо) </div>

# %% [markdown]
# #### Количество комнат

# %% [markdown]
# Построим гистограмму для параметра количество комнат:

# %%
# используем метод hist для построения гистограммы
data_filtered.hist('rooms');

# %% [markdown]
# Видим, что большая часть распределения лежит в диапазоне от 0 до 6, но на таком графике не видно деталей, попробуем взглянуть поближе. Сразу увеличим число корзин для наглядности

# %%
data_filtered.hist('rooms',bins=8, range=(0, 8))
plt.show()
data_filtered.hist('rooms',bins=5, range=(5, 10))
plt.show()

# %% [markdown]
# Квартир с более чем 7 комнатами - чуть более 50 из всего набора данных.
#
# Квартиры с 0 комнат оставим, может быть это студии
#
# Определим верхнюю границу в 6 комнат и построим график из среза

# %%
# методом query делаем срез данных
data_filtered.query('rooms < 7').hist('rooms', bins = 6);

# %%
# перезапишем в переменную датасет, с которым будем работать дальше
data_filtered = data_filtered.query('rooms < 7')

# %% [markdown]
# #### Высота потолков

# %% [markdown]
# Построим гистограмму и диаграмму размаха для параметра высота потолков:

# %%
# используем метод hist для построения гистограммы
data_filtered.hist('ceiling_height');

# %% [markdown]
# Видим, что большая часть распределения лежит в диапазоне от 0 до 10, но на таком графике не видно деталей, попробуем взглянуть поближе. Сразу увеличим число корзин для наглядности

# %%
data_filtered.hist('ceiling_height',bins=50, range=(2.5, 3.5));
plt.show()
data_filtered.hist('ceiling_height',bins=100, range=(20, 35))
plt.show()
data_filtered.hist('ceiling_height',bins=100, range=(80, 100))
plt.show()

# %% [markdown]
# На первой гистограмме видим основную долю значений. Диапазон от 2.5 метров до 3.5 метров будем считать рабочим. На средней гистограмме выделяются значений 25, 27, 32. Предположим, что должны быть вещественные числа и изменим их. На последнем графике виден выброс 100 метров. Его просто отбросим.
#
# Построим гистограмму по новым данным

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Привет, ревьюер! Спасибо, что проверяешь мою работу. Я не могу сделать замену значений 25, 27, 32. Пробовал через цикл, через индексацию. Не получается, подскажи мне  </div>

# %%
# методом query делаем срез данных
data_filtered.query('2.5 < ceiling_height < 3.5').hist('ceiling_height', bins = 20);

# %%
# перезапишем в переменную датасет, с которым будем работать дальше
data_filtered = data_filtered.query('2.5 <= ceiling_height <= 3.5')

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Заменять не нужно, лучше сделать срез через query, как ты это делаешь выше. Только тебе нужно перезаписать датасет, чтобы результат сохранился
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Перезаписал все срезы в новый датасет data_filtered :)</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# #### Тип этажа квартиры

# %% [markdown]
# Для этого параметра будем использовать метод plot с параметром bar, потому что столбец хранит категориальные значения

# %%
# используем метод plot для построения столбчатой диаграммы
data['floor_category'].value_counts().plot(kind='bar');

# %% [markdown]
# В этом столбце никаких аномалий не видно, идем дальше

# %% [markdown]
# #### Общее количество этажей в доме

# %% [markdown]
# Построим гистограмму и диаграмму размаха для параметра общее количество этажей в доме

# %%
# используем метод hist для построения гистограммы
data_filtered.hist('floors_total')
plt.show()
data_filtered.hist('floors_total', bins=20, range=(0, 30))
plt.show()
data_filtered.hist('floors_total', range=(50, 60))
plt.show()

# %% [markdown]
# Основная часть данных лежит в диапазоне до отметки 30
#
# Два выброса на значениях 52 и 60 отбросим, остальное оставим как есть
#
# Строим график по срезу:

# %%
# методом query делаем срез данных
data_filtered.query('floors_total < 50').hist('floors_total', bins=30, range=(0, 30));

# %%
# перезапишем в переменную датасет, с которым будем работать дальше
data_filtered = data_filtered.query('floors_total < 50')

# %% [markdown]
# #### Расстояние до центра города в метрах

# %% [markdown]
# Построим гистограмму и диаграмму размаха для параметра расстояние до центра города в метрах:

# %%
# вызовем метод describe для числовых данных
data_filtered['cityCenters_nearest'].describe()
# Out:
# count    16481.000000
# mean     14780.883789
# std       8475.130859
# min        287.000000
# 25%      10364.000000
# 50%      13479.000000
# 75%      16576.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %%
# используем метод hist для построения гистограммы
data_filtered.hist('cityCenters_nearest')
plt.show()
data_filtered.hist('cityCenters_nearest',bins=50, range=(0, 55000))
plt.show()
# методом boxplot строим график размаха
data_filtered.boxplot('cityCenters_nearest');
plt.ylim(0, 30000)
# Out:
# (0.0, 30000.0)

# %% [markdown]
# Для Петербуржцев центром является территория от набережной Обводного канала до Большой Невки.
# Это около 10 км в радиусе.
# Логично предположить, что нули в данных - это значит что квартира расположена прямо в центре города, поэтому эти данные не будем считать выбросами
#
# А вот верхнюю границу мы считаем нельзя устанавливать, потому что квартира может быть расположена в деревне в ленинградской области, далеко от центра, даже на расстоянии 60 км. Но это тоже будет влиять на ее стоимость

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Здесь верное решение не устанавливать верхнюю границу или нет? Что думаешь?  </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Верное)
# </div>

# %% [markdown]
# #### Расстояние до ближайшего парка

# %%
# вызовем метод describe для числовых данных
data_filtered['parks_nearest'].describe()
# Out:
# count    6982.000000
# mean      495.419373
# std       341.717255
# min         1.000000
# 25%       292.000000
# 50%       458.000000
# 75%       617.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %%
# используем метод hist для построения гистограммы
data_filtered.hist('parks_nearest');

# %% [markdown]
# Квартиры с парком ближе 1000 метров - уже редки. На участке более 1500 гистогамма уже сливается с нулем, значит таких квартир единицы

# %%
data_filtered.hist('parks_nearest',bins=100, range=(0, 3000));
plt.show()
data_filtered.boxplot('parks_nearest');
plt.ylim(0, 1500);

# %% [markdown]
# Мы считаем устанавливать верхнюю границу здесь нельзя, так как расстояние до парка влияет на конечную стоимость. Поэтому оставляем данные как есть

# %% [markdown]
# **Промежуточный вывод:**
#
# Для каждого параметра мы построили графики, которые показали какие значения - потенциальные выбросы. Некоторые из них мы удалили, некоторые оставили
#
# Общая площадь квартиры:
# Квартиры с площадью больше 100 - уже редки. На участке более 250 гистогамма уже сливается с нулем, значит таких квартир единицы.
# По диаграме размаха выбросы это все значения после 115
# Примем верхнюю границу в 150 квадратных метров. Если отбросить эти значения, много данных не потеряется
#
# Жилая площадь:
# После отметки 60 квадратных метров значения уже редки, после отметки в 100 значения сливаются с нулем.
# По ящику с усами выбросы - все что после 80
# Примем верхнюю границу в 80 квадратных метров, так много данных не потеряется
#
# Площадь кухни:
# После отметки 30 квадратных метров значения уже редки, после отметки в 40 значения сливаются с нулем.
# По ящику с усами выбросы - все что после 20
# Примем верхнюю границу в 20 квадратных метров, так много данных не потеряется
#
# Конечная цена:
# Цены больше 10 000 000 уже редки. После 30 000 000 гистограмма сливается с нулем. Определим верхнюю границу в 12 000 000, много данных не потеряется. Нижнюю границу определять не будем, так как там слишком мало данных, онм не исказят результаты
#
# Комнаты:
# Квартир с более чем 7 комнатами - чуть более 50 из всего набора данных.
# Квартиры с 0 комнат оставим, может быть это студии
#
#
# Потолки:
# На первой гистограмме видим основную долю значений. Диапазон от 2.5 метров до 3.5 метров будем считать рабочим. На последнем графике виден выброс 100 метров. Его просто отбросим.
#
# Этажей в доме:
# Основная часть данных лежит в диапазоне до отметки 30
# Два выброса на значениях 52 и 60 отбросим, остальное оставим как есть
#
# Расстояние до центра:
# Для Петербуржцев центром является территория от набережной Обводного канала до Большой Невки.
# Это около 10 км в радиусе.
# Логично предположить, что нули в данных - это значит что квартира расположена прямо в центре города, поэтому эти данные не будем считать выбросами
#
# А вот верхнюю границу мы считаем нельзя устанавливать, потому что квартира может быть расположена в деревне в ленинградской области, далеко от центра, даже на расстоянии 60 км. Но это тоже будет влиять на ее стоимость
#
# Расстояние до ближайшего парка:
# Здесь такая же ситуация, как в столбце расстояние до центра. Оставляем без верхней границы

# %% [markdown]
# Проверяем, что количество отброшенных данных не превышает 10% от изначального объема данных

# %%
# выводим количество строк для оригинального датасета и отфильтрованного, проверяем долю
display(
'В оригинальном датасете строк:', len(data),
'В отфильтрованном датасете строк:', len(data_filtered),
'Процент потерь:', (len(data) - len(data_filtered)) / len(data) * 100
)
# Out:
# 'В оригинальном датасете строк:'
# 23565
# 'В отфильтрованном датасете строк:'
# 21871
# 'Процент потерь:'
# 7.188627201357946

# %%
# еще раз выведем гистограммы по всем данным таблицы
data_filtered.hist(figsize=(15, 20));
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>В данном задании важно не просто определить границы для аномалий, а ещё удалить их в том датасете, с которым ты работаешь дальше. Нужно убрать аномальные значения для потолков, стоимости квартиры, площади и количества комнат. А количество отброшенных данных не должно превышать 10% от изначального объёма данных.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Удалил аномалии, перезаписал датасет, проверил количество отброшенных значений</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# ### Изучите, как быстро продавались квартиры

# %% [markdown]
# Изучим, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.

# %%
# методом describe выведем все числовые значения по столбцу
data_filtered['days_exposition'].describe()
# Out:
# count    19105.000000
# mean       174.916565
# std        213.387222
# min          1.000000
# 25%         44.000000
# 50%         92.000000
# 75%        222.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
f'Дольше всего объявление было размещено 1580 дней или {(1580 // 365)} года и {int((1580 % 365) / 30)} месяца'
# Out:
# 'Дольше всего объявление было размещено 1580 дней или 4 года и 4 месяца'

# %%
# используем метод hist для построения гистограммы
data_filtered.hist('days_exposition');
plt.show()
data_filtered.hist('days_exposition', range=(0, 250));
plt.show()
data_filtered.hist('days_exposition', range=(0, 30));
plt.show()
# методом boxplot построим диаграму размаха
data_filtered.boxplot('days_exposition');
plt.ylim(0, 600);

# %% [markdown]
# На графике очень много значений около нуля - неужели это выбросы? Не могут же так много квартиры продаваться так быстро. Построим гистограму с масштабом от 0 дней до 200 дней, где видно мощный пик. Видим нисходящий слева направо график и все равно много значений от 0 до 25 дней. Посмотрим сколко квартир продается за месяц после публикации объявления: продажи начинаются с 3-4 дня. В это можно поверить.

# %% [markdown]
# Обычно продажа занимает:
#
# - Среднее 180 дней
# - Медиана 95 дней
#
#
# Какие продажи можно считать быстрыми, а какие — необычно долгими?
#
# Продажи, завершенные менее, чем за 95 дней (медиана) можно считать быстрыми. Необычно долгие продажи - это продажи, которые не завершили за 200 дней.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Если интересно, то можно посмотреть на диапазон от 0 до 100 дней. Там есть пики, которым можно найти очень логичное объяснение</div>
# </div>

# %%
data_filtered.hist('days_exposition', range=(0, 100));
plt.show()

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Пики вижу. Логичное объеснение не вижу( Объясни, пожалуйста</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Это особенность функционирования системы размещения объявлений) Убедиться в этом можно по ссылке ниже
#
# 	https://yandex.ru/support/realty/owner/home/add-ads-housing.html
# </div>

# %% [markdown]
# ### Взаимосвязь данных

# %% [markdown]
# Попробуем выяснить если ли связь между конечной стоимостью квартиры и ее параметрами с помощью графиков:

# %% [markdown]
# Будем строить диаграмму рассеяния и находить корреляцию, а заодно проверим как изменились данные после срезов, которые мы предложиили

# %% [markdown]
# #### Взаимосвязь с общей площадью

# %%
# строим график по первичным данным
data.plot(
    x='last_price',
    y='total_area',
    style='o',
    grid=True,
    alpha=0.4
);

plt.show()

# строим график по срезу данных, который мы решили принять за рабочий диапазон
(data
    .query('last_price < 15000000')
    .plot(
    x='last_price', 
    y='total_area', 
    style='o', 
    grid=True,
    alpha=0.4
));
plt.show()

# %% [markdown]
# На первом графике видна взаимосвязь, но не так явно, как на втором
#
# После обработки данных график говорит о взаимосвязи между двумя величинами, на лицо положительная корреляция
#
# Посмотрим как измениалсь корреляция с оригинальным датафреймом

# %%
# методом corr смотрим корреляцию в оригинальном датафрейме
data['total_area'].corr(data['last_price'])
# Out:
# 0.6536213942411871

# %%
# методом corr смотрим корреляцию в отфильтрованном датафрейме
data_filtered['total_area'].corr(data_filtered['last_price'])
# Out:
# 0.7365072262734642

# %% [markdown]
# Для большей наглядности построим график hexbin по этим же данным

# %%
(data_filtered
    .plot(
    x='total_area', 
    y='last_price', 
    kind='hexbin', 
    gridsize=20, 
    figsize=(8, 6), 
    sharex=False, 
    grid=True)
 
);

# %% [markdown]
# Самая большая концентрация в диапазоне площади квартир 30-40 кв. метров и ценой 3-4 миллиона. Звучит вполне правдоподобно

# %% [markdown]
# #### Взаимосвязь с жилой площадью

# %%
# строим график по первичным данным
data.plot(
    x='living_area',
    y='last_price',
    style='o',
    grid=True,
    alpha=0.4
);

plt.show()

# строим график по срезу данных, который мы решили принять за рабочий диапазон
(data
    .query('living_area < 80')
    .plot(
    x='living_area', 
    y='last_price', 
    style='o',
    grid=True,
    alpha=0.4
));
plt.show()

# %% [markdown]
# На первом графике видно много значений после отметки 80 кв. метров, которую мы решили принять за верхнюю границу. Неужели мы совершили ошибку?
#
# Посмотрим корреляции

# %%
# методом corr смотрим корреляцию в оригинальном датафрейме
data['living_area'].corr(data['last_price'])
# Out:
# 0.5854309899315712

# %%
# методом corr смотрим корреляцию в отфильтрованном датафрейме
data_filtered['living_area'].corr(data_filtered['last_price'])
# Out:
# 0.6164671712554984

# %% [markdown]
# Корреляция увеличилась, что логично, потому что мы заполняли пропущенные значения с помощью соотношения. Но было ли правильным решение отсекать данные выше отметки в 80 кв. метров?

# %% [markdown]
# #### Взаимосвязь с площадью кухни

# %%
# строим график по первичным данным
data.plot(
    x='last_price',
    y='kitchen_area',
    style='o',
    grid=True,
    alpha=0.4
);

plt.show()

# строим график по срезу данных, который мы решили принять за рабочий диапазон
(data
    .query('kitchen_area < 30')
    .plot(
    x='last_price', 
    y='kitchen_area', 
    style='o',
    grid=True,
    alpha=0.4
));
plt.show()

# %% [markdown]
# Похожая ситуация с графиками по жилой площади. Посмотрим корреляции

# %%
# методом corr смотрим корреляцию в оригинальном датафрейме
data['kitchen_area'].corr(data['last_price'])
# Out:
# 0.47603379248508015

# %%
# методом corr смотрим корреляцию в отфильтрованном датафрейме
data_filtered['kitchen_area'].corr(data_filtered['last_price'])
# Out:
# 0.46369254892511313

# %% [markdown]
# Корреляция не изменилась

# %% [markdown]
# #### Взаимосвязь с количеством комнат

# %%
# строим график по первичным данным
data.plot(
    x='rooms',
    y='last_price',
    style='o',
    grid=True,
    alpha=0.4
);

plt.show()

# строим график по срезу данных, который мы решили принять за рабочий диапазон
(data
    .query('rooms < 7')
    .plot(
    x='rooms', 
    y='last_price', 
    style='o',
    grid=True,
    alpha=0.4
));
plt.show()

# %% [markdown]
# Логично увидеть, что с появлением комнат увеличивается и цена на квартиру

# %%
# методом corr смотрим корреляцию в оригинальном датафрейме
data['rooms'].corr(data['last_price'])
# Out:
# 0.3631905485065752

# %%
# отфильтрованные данные вынесем в переменную для удобства
data_filtered = data.query('rooms < 7')

# %%
# методом corr смотрим корреляцию в отфильтрованном датафрейме
data_filtered['rooms'].corr(data_filtered['last_price'])
# Out:
# 0.3669269184120544

# %% [markdown]
# Корреляция не изменилась

# %% [markdown]
# #### Взаимосвязь с этажом, на котором расположена квартира

# %% [markdown]
# Построим столбчатую диаграмму с зависимостью цены от типа этажа квартиры

# %%
# строим сводную таблицу и по ней строим график
(data_filtered
    .pivot_table(index='floor_category', 
                           values='last_price', 
                           aggfunc=['median', 'count', 'mean'])
    .plot(kind='bar', y = ['mean', 'median'], title='Зависимость цены от типа этажа квартиры')
);

# %% [markdown]
# Цена на квартиры на первом этаже самая низкая. Квартиры на последнем этаже ценяться чуть выше, но самые дорогие квартиры находятся на "другом" этаже - не первом и не последнем

# %% [markdown]
# <div class="alert alert-info"> <b>Я не смог построить график. Дай наводку...</b> </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Для категории этажа, дня, месяца и года продажи нужно построить barplot рассчитав среднее значение или медиану. После этого необходимо написать о зависимости цены от этих параметров
#
#     https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Спасибо. Разобрался, кажется</div>

# %% [markdown]
# #### Взаимосвязь от даты размещения

# %% [markdown]
# ##### День недели

# %%
# строим график по обработанным данным
(data_filtered
    .pivot_table(index='weekday_published', 
                          values='last_price', 
                          aggfunc=['count', 'mean', 'median'])
    .plot(
    kind='bar',
    y=['mean', 'median'],
    legend=False,
));

plt.show()

# %% [markdown]
# Каких то характерных выбросов для определенного дня график не показывает

# %% [markdown]
# ##### Месяц

# %%
# строим график по обработанным данным
(data_filtered
    .pivot_table(index='month_published', 
                          values='last_price', 
                          aggfunc=['count', 'mean', 'median'])
    .plot(
    kind='bar',
    y=['mean', 'median'],
    legend=False,
));

plt.show()

# %% [markdown]
# Кажется, что квартиры продаются весь год примерно за одинаковую цену

# %% [markdown]
# ##### Год

# %%
# строим график по обработанным данным
(data_filtered
    .pivot_table(index='year_published', 
                          values='last_price', 
                          aggfunc=['count', 'mean', 'median'])
    .plot(
    kind='bar',
    y=['mean', 'median'],
    legend=False,
));

plt.show()

# %% [markdown]
# 2014 год оказался самый выгодный для покупки. Проверим эту гипотезу, посмтроим сводную таблицу

# %%
(data_filtered
    .pivot_table(index='year_published', 
                          values='last_price', 
                          aggfunc=['count', 'mean', 'median']))
# Out:
#                     count          mean     median
#                last_price    last_price last_price
# year_published
# 2014                  136  1.204660e+07    7640000
# 2015                 1161  8.397373e+06    5300000
# 2016                 2736  6.773745e+06    4500000
# 2017                 8118  6.263764e+06    4500000
# 2018                 8468  5.900760e+06    4550000
# 2019                 2856  6.560887e+06    5010000

# %% [markdown]
# Оказалось, что за 2014 год всего 104 наблюдения. Конечно, мы не можем делать вывод по таким скудным данным, поэтому уберем из анализа данные за 2014 год.
#
# Распределение цены по годам примерно одинаковое. Не можем сказать, что год влиял на цену

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Зависимость цены изучена верно! Ещё тут можно использовать для визуализации pairplot из библиотеки seaborn
#
#     https://seaborn.pydata.org/generated/seaborn.pairplot.html
# </div>

# %% [markdown]
# ### Топ 10 населенных пунктов по цене за квадратный метр

# %% [markdown]
# Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений — построим сводную таблицу с количеством объявлений и средней ценой квадратного метра для этих населенных пунктов

# %%
# методом pivot_table строим сводную таблицу и методом sort_values сортируем
best_sqm_price = (data_filtered
 .pivot_table(
     index='locality_name', 
     values='sqm_price', 
     aggfunc=['count', 'mean'])
)

# %%
# переименуем столбцы для удобства
best_sqm_price.columns = ['count', 'mean']

# %%
# округлим среднюю цену для удобства
best_sqm_price['mean'] = best_sqm_price['mean'].round(1)

# %%
# выводим первые 10 позиций
best_sqm_price.sort_values(by='count', ascending=False).head(10)
# Out:
#                    count      mean
# locality_name
# Санкт-Петербург    15564  114613.9
# поселок Мурино       552   85629.6
# поселок Шушары       439   78551.3
# Всеволожск           398   68654.5
# Пушкин               368  103100.9
# Колпино              337   75333.3
# поселок Парголово    326   90332.3
# Гатчина              307   68746.1
# деревня Кудрово      299   92473.5
# Выборг               237   58141.9

# %% [markdown]
# Таблица показывает местность, где было размещено больше всего объявлений и среднюю стоимость за 1 кв.метр в этой местности
#
# Самый дорогой квадратный метр в Санкт-Петербурге - 108311 рублей
#
# Самый дешевый квадратный метр в Выборге - 58135 рублей

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Тебе сначала нужно найти топ10 населённых пунктов по количеству объявлений и уже в этом списке рассчитать среднюю стоимость за квадратный метр и выделить топ1 и топ10
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Да, понял. Переделал. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# ### Найдем среднюю стоимость квартир по мере удаления от центра города

# %% [markdown]
# Ранее мы посчитали расстояние до центра в километрах. Теперь выделим квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислим их среднюю стоимость на разном удалении от центра.

# %%
price_for_distance = (data
.pivot_table(index='cityCenter_distance_km', values=['last_price'], aggfunc='mean')
.round(2)
.sort_values(by='cityCenter_distance_km', ascending=True)
.reset_index()
.query('cityCenter_distance_km < 10')
.plot(
    x='cityCenter_distance_km',
    y='last_price',
    style='o-',
    grid=True,
    alpha=1)
);

# %% [markdown]
# На этом графике видно, как стоимость квартир постепенно падает по мере их удаления от центра города. На значении 0 квартиры, которые находяться внутри черты центра города, они самые дорогие. Через 1 км стоимость падает уже почти в 1.5 раза, на расстоянии 3 км от центра стоимость уже в два раза меньше.  Однако, дальше по расстоянию виден небольшой подъем, и снова спад

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отличный анализ 👍
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Мы обработали и проанализировали данные архива Яндекс Недвижимости, нашли в данных пропуски, неочевидные дубликаты, аномальные значения, создали новые стоблцы на основе имеющихся данных, построили графики, нашли взаимосвязи.
#
# В ходе исследовательского анализа было выявлено и обработано немало аномалий. Мы попытались обработать большую часть выбросов.
#
# Общий вывод можно сделать такой:
#
# - Обнаружили положительную корреляцию между параметрами цены и общей площади
# - Чем больше комнат, тем цена выше
# - Квартиры, которые были выставлены на продажи по субботам и воскресеньям продаются дешевле
# - Квартиры выставленные на продажу в мае продавались дешевле
# - 2014 год оказался самый выгодный для покупки
#
# Самые высокие цены за квадратный метр в Зеленогорске, Санкт-Петербурге и поселке Репино
#
#
# Стоимость квартир постепенно падает по мере их удаления от центра города. Квартиры, которые находяться внутри черты центра города, они самые дорогие. Через 1 км стоимость падает уже почти в 1.5 раза, на расстоянии 3 км от центра стоимость уже в два раза меньше. Однако, дальше по расстоянию виден небольшой подъем, и снова спад.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Спасибо за уделенное время. Я старался, пытался выложиться на максимум. Пожалуйста, скажи что мне исправить и над чем поработать. Спасибо! </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v1:</b>
# <br>Необходимо поправить:
# <br>- отбросить аномальные значения
# <br>- корректно изучить зависимость цены от категории этажа и времени публикации объявления
# <br>- корректно изучить топ10 населённых пунктов с наибольшим числом объявлений
#
# <br>После всех внесённых правок не забудь поправить выводы там, где это необходимо
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Илья, ну вроде все исправил</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Итоговый комментарий ревьюера v2:</b>
# <br>Все правки выполнены. Молодец!
# <br>Я рад был поработать над проверкой твоей работы) В качестве дополнительного материала для изучения могу порекомендовать следующий ресурс:
#
# 	https://www.python-graph-gallery.com/
# <br>В нем содержится большая библиотека графиков с готовым кодом, который можно использовать при работе.
# <br>Поздравляю со сдачей проекта и желаю удачи в дальнейшем обучении! 😉
# </div>
